# %% [markdown]
# We now evaluate the models. We start by comparing the counts of false positives to false negatives for each model, but now they are evaluated on the same continuous day sample of daily living.

# %%
import sys
import os
import torch

sys.path.append(os.path.abspath('..')) #so we can import for the dir above

from SimpleCNN import SimpleCNN
from eval_in_time_domain import eval_in_time_domain

# %%
RECODING_TO_EVAL_ON = '/home/kuba/Documents/data/raw/kuba_watch_data/2024-07-10_06_42_46'
PATH_TO_BOUT_DIR = '/home/kuba/Documents/data/raw/listerine/3_final'


WINDOW_SIZE = 400
STRIDE = 50
CONFIDANCE_THRESHOLD = 0.95
OVERLAP_THRESHOLD = 0.30
MIN_BOUT_LEN = 400
NUM_BOUT_TO_SAMP = 45
DEVICE = 'cuda:0'

# %% [markdown]
# We know the results from model00 so we will not re-eval and jsut eval on our new model with 9% macro f1 !

# %%
#load model00
model00_path = '/home/kuba/projects/medication-taking-data/new_start/week03/02_oversamp_daily/93f1_overSampDaily_065fp.pth'
model = SimpleCNN()
model.load_state_dict(torch.load(model00_path))

#get false postive count

TP, TN, FP, FN, total = eval_in_time_domain(model, path_to_daily_dir=RECODING_TO_EVAL_ON, path_to_bout_dir=PATH_TO_BOUT_DIR, window_size=WINDOW_SIZE, stride=STRIDE, 
                                            confidance_threshold_for_mean=CONFIDANCE_THRESHOLD, overlap_threshold=OVERLAP_THRESHOLD, min_bout_len=MIN_BOUT_LEN, 
                                            num_bouts_to_samp=NUM_BOUT_TO_SAMP, device=DEVICE)
# Out:
# WARNING we will sample bouts from all participants there will be data leakage, unless you specify who not to sample from
# Bout shape - Acc: 435, Gyro: 435
# Bout shape - Acc: 471, Gyro: 471
# Bout shape - Acc: 405, Gyro: 405
# Bout shape - Acc: 648, Gyro: 648
# Bout shape - Acc: 417, Gyro: 417
# Bout shape - Acc: 599, Gyro: 599
# Bout shape - Acc: 496, Gyro: 496
# Bout shape - Acc: 494, Gyro: 494
# Bout shape - Acc: 439, Gyro: 439
# Bout shape - Acc: 497, Gyro: 497
# Bout shape - Acc: 695, Gyro: 695
# Bout shape - Acc: 417, Gyro: 417
# Bout shape - Acc: 643, Gyro: 643
# Bout shape - Acc: 1500, Gyro: 1500
# Bout shape - Acc: 470, Gyro: 470
# Bout shape - Acc: 945, Gyro: 945
# Bout shape - Acc: 424, Gyro: 424
# Bout shape - Acc: 454, Gyro: 454
# Bout shape - Acc: 535, Gyro: 535
# Bout shape - Acc: 469, Gyro: 469
# Bout shape - Acc: 455, Gyro: 455
# Bout shape - Acc: 596, Gyro: 596
# Bout shape - Acc: 926, Gyro: 926
# Bout shape - Acc: 468, Gyro: 468
# Bout shape - Acc: 435, Gyro: 435
# Bout shape - Acc: 470, Gyro: 470
# Bout shape - Acc: 419, Gyro: 419
# Bout shape - Acc: 448, Gyro: 448
# Bout shape - Acc: 489, Gyro: 489
# Bout shape - Acc: 469, Gyro: 469
# Bout shape - Acc: 891, Gyro: 891
# Bout shape - Acc: 420, Gyro: 420
# Bout shape - Acc: 450, Gyro: 450
# Bout shape - Acc: 446, Gyro: 446
# Bout shape - Acc: 495, Gyro: 495
# Bout shape - Acc: 792, Gyro: 792
# Bout shape - Acc: 521, Gyro: 521
# Bout shape - Acc: 484, Gyro: 484
# Bout shape - Acc: 420, Gyro: 420
# Bout shape - Acc: 419, Gyro: 419
# Bout shape - Acc: 499, Gyro: 499
# Bout shape - Acc: 491, Gyro: 491
# Bout shape - Acc: 792, Gyro: 792
# Bout shape - Acc: 695, Gyro: 695
# Bout shape - Acc: 455, Gyro: 455
# The recording partitioned into windows has shape of: torch.Size([51912, 6, 400])
# /home/kuba/.virenv/base/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# There are 4 FP's of 37 total peaks (confidance over: 0.95 and does not overlap with bout threshold:0.3)
# FP's are at rate of 10.81%
# TP's are at rate of 89.1892%
# Out of 45 model found 33 (73.33)
# Normalized on True

# %%
#load model01
model01_path = '/home/kuba/projects/medication-taking-data/new_start/week03/02_oversamp_daily/93f1_overSampDaily_048fp.pth'
model = SimpleCNN()
model.load_state_dict(torch.load(model01_path))
#get false postive count
TP, TN, FP, FN, total = eval_in_time_domain(model, path_to_daily_dir=RECODING_TO_EVAL_ON, path_to_bout_dir=PATH_TO_BOUT_DIR, window_size=WINDOW_SIZE, stride=STRIDE, 
                                            confidance_threshold_for_mean=CONFIDANCE_THRESHOLD, overlap_threshold=OVERLAP_THRESHOLD, min_bout_len=MIN_BOUT_LEN, 
                                            num_bouts_to_samp=NUM_BOUT_TO_SAMP, device=DEVICE)
# Out:
# WARNING we will sample bouts from all participants there will be data leakage, unless you specify who not to sample from
# Bout shape - Acc: 439, Gyro: 439
# Bout shape - Acc: 670, Gyro: 670
# Bout shape - Acc: 626, Gyro: 626
# Bout shape - Acc: 495, Gyro: 495
# Bout shape - Acc: 439, Gyro: 439
# Bout shape - Acc: 1287, Gyro: 1287
# Bout shape - Acc: 524, Gyro: 524
# Bout shape - Acc: 648, Gyro: 648
# Bout shape - Acc: 476, Gyro: 476
# Bout shape - Acc: 586, Gyro: 586
# Bout shape - Acc: 400, Gyro: 400
# Bout shape - Acc: 740, Gyro: 740
# Bout shape - Acc: 495, Gyro: 495
# Bout shape - Acc: 469, Gyro: 469
# Bout shape - Acc: 415, Gyro: 415
# Bout shape - Acc: 647, Gyro: 647
# Bout shape - Acc: 572, Gyro: 572
# Bout shape - Acc: 595, Gyro: 595
# Bout shape - Acc: 628, Gyro: 628
# Bout shape - Acc: 504, Gyro: 504
# Bout shape - Acc: 559, Gyro: 559
# Bout shape - Acc: 630, Gyro: 630
# Bout shape - Acc: 455, Gyro: 455
# Bout shape - Acc: 650, Gyro: 650
# Bout shape - Acc: 430, Gyro: 430
# Bout shape - Acc: 694, Gyro: 694
# Bout shape - Acc: 416, Gyro: 416
# Bout shape - Acc: 594, Gyro: 594
# Bout shape - Acc: 470, Gyro: 470
# Bout shape - Acc: 450, Gyro: 450
# Bout shape - Acc: 624, Gyro: 624
# Bout shape - Acc: 454, Gyro: 454
# Bout shape - Acc: 496, Gyro: 496
# Bout shape - Acc: 459, Gyro: 459
# Bout shape - Acc: 495, Gyro: 495
# Bout shape - Acc: 670, Gyro: 670
# Bout shape - Acc: 546, Gyro: 546
# Bout shape - Acc: 523, Gyro: 523
# Bout shape - Acc: 471, Gyro: 471
# Bout shape - Acc: 744, Gyro: 744
# Bout shape - Acc: 494, Gyro: 494
# Bout shape - Acc: 426, Gyro: 426
# Bout shape - Acc: 400, Gyro: 400
# Bout shape - Acc: 594, Gyro: 594
# Bout shape - Acc: 547, Gyro: 547
# The recording partitioned into windows has shape of: torch.Size([51912, 6, 400])
# /home/kuba/.virenv/base/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# There are 9 FP's of 36 total peaks (confidance over: 0.95 and does not overlap with bout threshold:0.3)
# FP's are at rate of 25.00%
# TP's are at rate of 75.0000%
# Out of 45 model found 27 (60.00)
# Normalized on True

# %% [markdown]
# LETS GO MODEL IS EVEN BETTER!
